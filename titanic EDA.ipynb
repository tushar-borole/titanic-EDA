# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# ## EDA
#
# 1.  Is the variable categorical or continuous
#
# 2.  Are there missing values?
#
# 3. Min, Max, Mean, and Standard Deviation of the continuous variables.
#
# 4. Histograms describing the distribution of the variable.
#
# 5.  EDA should be completed for these fields:  'PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', and 'Embarked'

# %% [markdown]
# ## 1) PassengerId

# %%
df.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# 291    1
# 290    1
# 289    1
# 288    1
# 287    1
# 286    1
# 285    1
# 284    1
# 283    1
# 282    1
# 281    1
# 305    1
# 307    1
# 279    1
# 321    1
#       ..
# 561    1
# 560    1
# 584    1
# 585    1
# 586    1
# 587    1
# 610    1
# 609    1
# 608    1
# 607    1
# 606    1
# 605    1
# 604    1
# 603    1
# 602    1
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# Name: PassengerId, dtype: int64

# %%
df[df.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.PassengerId.describe()
# Out:
# count    891.000000
# mean     446.000000
# std      257.353842
# min        1.000000
# 25%      223.500000
# 50%      446.000000
# 75%      668.500000
# max      891.000000
# Name: PassengerId, dtype: float64

# %%
df.PassengerId.hist(bins=5)

# %% [markdown]
# <b>From above EDA for field PassengerID it is proved that</b>
# <ul>
# <li><h4 style="color:green">Variable PassengerID is continous<h4></li>
# <li><h4 style="color:green">There are no missing values<h4></li>
# </ul>

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df[df.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Survived.hist()

# %% [markdown]
# <b>From above EDA for field Survived it is proved that</b>
# <ul>
# <li><h4 style="color:green">Variable Survived is categorical<h4></li>
# <li><h4 style="color:green">There are no missing values<h4></li>
# </ul>

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df[df.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Pclass.hist()

# %% [markdown]
# <b>From above EDA for field Pclass it is proved that</b>
# <ul>
# <li><h4 style="color:green">Variable Pclass is categorical<h4></li>
# <li><h4 style="color:green">There are no missing values<h4></li>
# </ul>

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df[df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Sex.value_counts().plot(kind='bar')

# %% [markdown]
# <b>From above EDA for field Sex it is proved that</b>
# <ul>
# <li><h4 style="color:green">Variable Sex is categorical<h4></li>
# <li><h4 style="color:green">There are no missing values<h4></li>
# </ul>

# %%
df.Age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 30.00    25
# 28.00    25
# 19.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 32.00    18
# 27.00    18
# 35.00    18
# 26.00    18
# 16.00    17
# 31.00    17
# 23.00    15
# 34.00    15
# 33.00    15
# 20.00    15
# 39.00    14
# 17.00    13
# 40.00    13
# 42.00    13
# 45.00    12
# 38.00    11
# 50.00    10
# 2.00     10
# 4.00     10
# 47.00     9
#          ..
# 28.50     2
# 40.50     2
# 63.00     2
# 13.00     2
# 10.00     2
# 45.50     2
# 70.00     2
# 30.50     2
# 71.00     2
# 59.00     2
# 57.00     2
# 55.00     2
# 0.75      2
# 64.00     2
# 23.50     1
# 14.50     1
# 0.67      1
# 53.00     1
# 0.92      1
# 0.42      1
# 70.50     1
# 36.50     1
# 80.00     1
# 66.00     1
# 74.00     1
# 12.00     1
# 55.50     1
# 34.50     1
# 24.50     1
# 20.50     1
# Name: Age, dtype: int64

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df.Age.describe()
# Out:
# C:\Users\Tushar\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max       80.000000
# Name: Age, dtype: float64

# %%
df.Age.hist(bins=5)

# %% [markdown]
# <b>From above EDA for field Age it is proved that</b>
# <ul>
# <li><h4 style="color:green">Variable Age is continous<h4></li>
# <li><h4 style="color:green">There are missing values<h4></li>
# </ul>

# %%
df.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
df[df.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.SibSp.hist(bins=5)

# %% [markdown]
# <b>From above EDA for field SibSp it is proved that</b>
# <ul>
# <li><h4 style="color:green">Variable SibSp is categorical <h4></li>
# <li><h4 style="color:green">There are missing values<h4></li>
# </ul>

# %%
df.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
df[df.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Parch.hist(bins=5)

# %% [markdown]
# <b>From above EDA for field Parch it is proved that</b>
# <ul>
# <li><h4 style="color:green">Variable Parch is categorical <h4></li>
# <li><h4 style="color:green">There are no missing values<h4></li>
# </ul>

# %%
df.Ticket.value_counts()
# Out:
# CA. 2343             7
# 347082               7
# 1601                 7
# 347088               6
# CA 2144              6
# 3101295              6
# 382652               5
# S.O.C. 14879         5
# PC 17757             4
# 4133                 4
# LINE                 4
# 349909               4
# 347077               4
# W./C. 6608           4
# 113760               4
# 2666                 4
# 113781               4
# 19950                4
# 17421                4
# 347742               3
# 239853               3
# 110152               3
# 24160                3
# 13502                3
# PC 17572             3
# C.A. 34651           3
# 248727               3
# 35273                3
# F.C.C. 13529         3
# PC 17755             3
#                     ..
# 330877               1
# 315094               1
# 236852               1
# 4137                 1
# 4136                 1
# 226593               1
# 4134                 1
# 374746               1
# 110813               1
# ...

# %%
df[df.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Ticket.describe()
# Out:
# count          891
# unique         681
# top       CA. 2343
# freq             7
# Name: Ticket, dtype: object

# %%
df.Ticket.value_counts().plot(kind='bar')

# %% [markdown]
# <b>From above EDA for field Tickit it is proved that</b>
# <ul>
# <li><h4 style="color:green">Variable Tickit is continuous <h4></li>
# <li><h4 style="color:green">There are no missing values<h4></li>
# </ul>

# %%
df.Fare.value_counts()
# Out:
# 8.0500      43
# 13.0000     42
# 7.8958      38
# 7.7500      34
# 26.0000     31
# 10.5000     24
# 7.9250      18
# 7.7750      16
# 7.2292      15
# 26.5500     15
# 0.0000      15
# 8.6625      13
# 7.8542      13
# 7.2500      13
# 7.2250      12
# 9.5000       9
# 16.1000      9
# 15.5000      8
# 24.1500      8
# 14.5000      7
# 7.0500       7
# 56.4958      7
# 52.0000      7
# 69.5500      7
# 31.2750      7
# 14.4542      7
# 27.9000      6
# 7.7958       6
# 30.0000      6
# 26.2500      6
#             ..
# 6.9500       1
# 15.0500      1
# 21.6792      1
# 7.1417       1
# 15.0458      1
# 4.0125       1
# 12.0000      1
# 8.4583       1
# 7.7875       1
# 14.0000      1
# 15.0000      1
# 9.8417       1
# 12.2750      1
# 12.2875      1
# 22.5250      1
# 6.4500       1
# 15.5500      1
# 8.5167       1
# 63.3583      1
# 6.8583       1
# 22.0250      1
# 13.7917      1
# 221.7792     1
# 12.6500      1
# 8.8500       1
# 61.1750      1
# 10.1708      1
# ...

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df.Fare.hist(bins=5)

# %% [markdown]
# <b>From above EDA for field Fare it is proved that</b>
# <ul>
# <li><h4 style="color:green">Variable Fare is continuous <h4></li>
# <li><h4 style="color:green">There are no missing values<h4></li>
# </ul>

# %%
df.Cabin.value_counts()
# Out:
# C23 C25 C27        4
# G6                 4
# B96 B98            4
# D                  3
# C22 C26            3
# E101               3
# F2                 3
# F33                3
# B57 B59 B63 B66    2
# C68                2
# B58 B60            2
# E121               2
# D20                2
# E8                 2
# E44                2
# B77                2
# C65                2
# D26                2
# E24                2
# E25                2
# B20                2
# C93                2
# D33                2
# E67                2
# D35                2
# D36                2
# C52                2
# F4                 2
# C125               2
# C124               2
#                   ..
# F G63              1
# A6                 1
# D45                1
# D6                 1
# D56                1
# C101               1
# C54                1
# D28                1
# D37                1
# B102               1
# D30                1
# E17                1
# ...

# %%
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %%
df.Cabin.describe()
# Out:
# count             204
# unique            147
# top       C23 C25 C27
# freq                4
# Name: Cabin, dtype: object

# %% [markdown]
# <b>From above EDA for field Cabin it is proved that</b>
# <ul>
# <li><h4 style="color:green">Variable Fare is continuous <h4></li>
# <li><h4 style="color:green">There are missing values<h4></li>
# </ul>

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df[df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df.Embarked.describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
df.Embarked.value_counts().plot(kind='bar')

# %% [markdown]
# <b>From above EDA for field Embarked it is proved that</b>
# <ul>
# <li><h4 style="color:green">Variable Embarked is categorical <h4></li>
# <li><h4 style="color:green">There are missing values<h4></li>
# </ul>
